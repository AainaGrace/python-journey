# %% [markdown]
# <a href="https://colab.research.google.com/github/AainaGrace/python-journey/blob/main/Task_01_My_Digital_Identity.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# Task 1 - My Didital Identity
name = "Aaina Grace"
reg_no ="JSOFT26261"
department ="BCA"
semester = 1
skills = "Problem Solving, observation"
hobbies = "Karate, Learning new things"
dream_company = "Google"
github = "https://github.com/AainaGrace"
linkedin = "https://www.linkedin.com/in/aaina-grace-536692422?utm_source=share_via&utm_content=profile&utm_medium=member_android"
career_goal="Start a business | Travel a lot |"

print ("=" * 40)
print ("        MY DIGITAL IDENTITY")
print ("=" * 40)
print(f"Name               : {name}")
print(f"Reg Number         : {reg_no}")
print(f"Department         : {department}")
print(f"Semester           : {semester}")
print(f"Skills             : {skills}")
print(f"Hobbies            : {hobbies}")
print(f"Dream Company      : {dream_company}")
print(f"Github             : {github}")
print(f"Linkedin           : {linkedin}")
print(f"Career Goal        : {career_goal}")
print("=" * 40)
# Out:
# ...
#         MY DIGITAL IDENTITY
# ...
# Name               : Aaina Grace
# Reg Number         : JSOFT26261
# Department         : BCA
# Semester           : 1
# Skills             : Problem Solving, observation
# Hobbies            : Karate, Learning new things
# Dream Company      : Google
# Github             : https://github.com/AainaGrace
# Linkedin           : https://www.linkedin.com/in/aaina-grace-536692422?utm_source=share_via&utm_content=profile&utm_medium=member_android
# Career Goal        : Start a business | Travel a lot |
# ...
