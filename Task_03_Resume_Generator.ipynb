# %% [markdown]
# <a href="https://colab.research.google.com/github/AainaGrace/python-journey/blob/main/Task_03_Resume_Generator.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# Task 3 - Resume Generator
name = input("Full Name: ")
education = input("Education: ")
skills = input("Skills (comma seperated): ")
projects = input("Projects (comma seperated): ")
languages = input("Languages known: ")

print("\n" + "=" * 45)
print(f"{name.upper():^45}")
print("=" * 45)
print("\nEDUCATION")
print("-" * 45)
print(education)
print("\nSKILLS")
print("-" * 45)
for s in skills.split(","):
    print(f"  • {s.strip()}")
print("\nPROJECTS")
print("-" * 45)
for p in projects.split(","):
    print(f"   • {p.strip()}")
print("\nLANGUAGES")
print("-" * 45)
print(languages)
print("=" * 45)
# Out:
# Full Name: Aaina Grace
# Education: Plus Two
# Skills (comma seperated): Problem Solving, Communication
# Projects (comma seperated): My Digital Identitty, Student Profile Manager
# Languages known: English Malayalam Hindi
#
# ...
#                  AAINA GRACE
# ...
#
# EDUCATION
# ---------------------------------------------
# Plus Two
#
# SKILLS
# ---------------------------------------------
#   • Problem Solving
#   • Communication
#
# PROJECTS
# ---------------------------------------------
#    • My Digital Identitty
#    • Student Profile Manager
#
# LANGUAGES
# ---------------------------------------------
# English Malayalam Hindi
# ...
