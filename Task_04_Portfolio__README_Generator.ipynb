# %% [markdown]
# <a href="https://colab.research.google.com/github/AainaGrace/python-journey/blob/main/Task_04_Portfolio__README_Generator.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# Task 04 Portfolio README Generator

name = input("Your name: ")
department = input("Department: ")
university = input("University: ")
skills = input("Skills (comma-separated): ")
projects = input("Projects (comma-separated): ")
github = input("GitHub link: ")
linkedin = input("Linkedin link: ")
email = input("Email: ")

readme = f"""# Hi, I'm {name}!

## About Me
I am a student from the **{department}** department at **{university}**.
I am interested in learning, building projects, and growing my technical skills.

## Skills
{skills}

## Projects
{projects}

## Connect With Me
- GitHub: {github}
- Linkedin: {linkedin}
- Email: {email}

Thanks for visiting my profile!
"""
# Out:
# Your name: Aaina Grace
# Department: Work-Integrated BCA
# University: Jain Deemed-to-be University
# Skills (comma-separated): Problem Solving, Communication
# Projects (comma-separated): My Digital Identity, Student Profile Manager, Resume Generator
# GitHub link: https://github.com/AainaGrace
# LinkedIn link: https://www.linkedin.com/in/AainaGrace/nEmail: aainagrace25@gmail.com
# # Hi, I'm Aaina Grace!
#
# ## About Me
# I am a student from the **Work-Integrated BCA** department at **Jain Deemed-to-be University**.
# I am interested in learning, building projects, and growing my technical skills.
#
# ## Skills
# Problem Solving, Communication
#
# ## Projects
# My Digital Identity, Student Profile Manager, Resume Generator
#
# ## Connect With Me
# - GitHub: https://github.com/AainaGrace
# - Linkedin: https://https://www.linkedin.com/in/AainaGrace
# - Email: aainagrace25@gmail.com
#
#  Thanks for visiting my profile!
