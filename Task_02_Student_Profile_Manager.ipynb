# %% [markdown]
# <a href="https://colab.research.google.com/github/AainaGrace/python-journey/blob/main/Task_02_Student_Profile_Manager.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# Task 2 - Student Profile Manager
name = input("Name:")
age = int(input("Age: "))
department = input("Deparment: ")
cgpa = float(input("CGPA: "))
blood_group =input("Blood Group: ")
email = input("Email: ")
phone = input("Phone:")

print("/n" +"=" * 40)
print("        STUDENT PROFILE")
print("=" * 40)
print(f"Name         : {name}")
print(f"Age          : {age}")
print(f"Department   : {department}")
print(f"CGPA         : {cgpa}")
print(f"Blood Group  : {blood_group}")
print(f"Email        : {email}")
print(f"Phone        : {phone}")
print("=" * 45)
# Out:
# Name:Aaina Grace
# Age: 18
# Deparment: Work-Integrated BCA
# CGPA: 9.1
# Blood Group: O-ve
# Email: aainagrace25@gmail.com
# Phone:9744391804
# /n========================================
#         STUDENT PROFILE
# ...
# Name         : Aaina Grace
# Age          : 18
# Department   : Work-Integrated BCA
# CGPA         : 9.1
# Blood Group  : O-ve
# Email        : aainagrace25@gmail.com
# Phone        : 9744391804
# ...
